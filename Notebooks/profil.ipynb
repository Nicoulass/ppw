# %% [markdown]
# # Profil Mahasiswa
#
# ---
#
# ## Muhammad Rafi Lazuardi
#
# | | |
# |---|---|
# | **NPM** | 23-060 |
# | **Email** | [lazuardirafi59@gmail.com](mailto:lazuardirafi59@gmail.com) |
# | **Program Studi** | Teknik Informatika |
# | **Mata Kuliah** | Pencarian & Penambangan Web |
# | **Semester** | 7 |
#
# ---
#
# ## Tentang Saya
#
# Halo! Saya **Muhammad Rafi Lazuardi**, mahasiswa semester 7 yang sedang menempuh mata kuliah **Pencarian & Penambangan Web** (Web Mining). Website ini merupakan kumpulan catatan dan materi perkuliahan yang dibangun menggunakan **Jupyter Book** dan **MyST Markdown**.
#
# ## Tentang Website Ini
#
# Website ini berisi:
#
# - **Profil** — Informasi tentang penulis
# - **Materi Perkuliahan** — Catatan dan eksperimen terkait Web Mining
#
# ### Teknologi yang Digunakan
#
# - 🐍 **Python** — Bahasa pemrograman utama
# - 📓 **Jupyter Notebook** — Untuk menulis catatan interaktif
# - 📖 **Jupyter Book (MyST)** — Untuk membangun website statis
# - 🌐 **GitHub Pages** — Untuk hosting website
# - 🕷️ **Trafilatura** — Library untuk web scraping & text extraction
